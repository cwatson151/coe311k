# %% [markdown]
# # Part A

# %% [markdown]
# Jacobi Method

# %%
import numpy as np
import time
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print(x)
    return x, max_iterations

# %%
# Example usage
A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start 

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {elapsed_time:.6e} seconds")
# Out:
# [1 2 2 3 4]
# Solution: [1 2 2 3 4]
# Iterations: 1
# Time: 1.304221e-03 seconds

# %% [markdown]
# Gauss-Seidel Method

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    print(x)
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print(x)
    return x, max_iterations

# %%
# Example usage
A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {elapsed_time:.6e} seconds")
# Out:
# [0 0 0 0 0]
# [1 2 2 2 4]
# [1 2 2 3 4]
# Solution: [1 2 2 3 4]
# Iterations: 2
# Time: 1.786099e-03 seconds

# %% [markdown]
# Convergence Comparison -Iteration: The Jacobi required fewer passes through the equations than the Jacobi method to reach the solution. -Decay: The size of the vectors in the Gauss-Seidel method decreased more rapidly than they did in the Jacobi method. -Time: The Jacobi method was slightly faster in reaching the solution than the Jacobi method was.

# %% [markdown]
# # Part B

# %% [markdown]
# Jacobi Method

# %%
import numpy as np
import time
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print(x)
    return x, max_iterations

# %%
# Example usage
A = np.array([[1, 2, 3, 0, 0],
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3],
              [0, 3, 2, 1, 2],
              [0, 0, 3, 2, 1]])
b = np.array([14, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start 

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {elapsed_time:.6e} seconds")
# Out:
# [14 22 33 26 22]
# [-129 -150 -171 -150 -129]
# [ 827 1072 1407 1076  835]
# [-6351 -7674 -9249 -7674 -6351]
# [43109 54244 68835 54248 43117]
# [-314979 -386610 -475629 -386610 -314979]
# [2200121 2741068 3436347 2741072 2200129]
# [-15791163 -19496130 -24164997 -19496130 -15791163]
# [111487265 138400732 172731531 138400736 111487273]
# [ -794996043  -983639778 -1222526517  -983639778  -794996043]
# [5634859121 6985964476 8704535403 6985964480 5634859129]
# [-40085535147 -49636682466 -61753012629 -49636682466 -40085535147]
# [284532402833 352587142972 439059940779 352587142976 284532402841]
# [-2022354108267 -2504946116130 -3117542988885 -2504946116130
#  -2022354108267]
# [14362521198929 17794632542716 22153909114155 17794632542720
#  14362521198937]
# [-102050992427883 -126416758254306 -157353657364437 -126416758254306
#  -102050992427883]
# [ 724894488601937  898059574347580 1117972987584555  898059574347584
#   724894488601945]
# [-5150038111448811 -6379913675415714 -7941605229001941 -6379913675415714
#  -5150038111448811]
# [36584643037837264 45323027707148672 56419883370355752 45323027707148672
#  36584643037837272]
# [-259905705525364576 -321978135937832000 -400799969055618240
#  -321978135937832064 -259905705525364576]
# [1846356179042518784 2287345756975461888 2847346776903515648
#  2287345756975461632 1846356179042518784]
# [ 5330012229048081408  2197300890891097856 -1780776028447408128
#   2197300890891097088  5330012229048081408]
# [  947726303560028672  4756368999834913792 -3875788790433775104
#   4756368999834911744   947726303560030208]
# [ 2114628371631497728 -8412982025757242368 -6265089746990275584
#  -8412982025757251584  2114628371631501824]
# [-1272254854933791744 -3353619319429792768  2517413799530437632
#  -3353619319429828608 -1272254854933773312]
# [-845002759731727360 7570540069096194048 2601262333612386304
#  7570540069096049664 -845002759731655680]
# [-4498123065319995392 -7777395281339915264 -6765399644284786688
#  -7777395281340491776 -4498123065319706624]
# [-1042498651884912640  8965743115811936256  2758087296151265280
#   8965743115809629184 -1042498651883759616]
# [-7759004046368116736  6565081511457510400  7285507595481989120
#   6565081511448283136 -7759004046363502592]
# [1906802338058115072 -301507558863042560 1846954158673719296
#  -301507558899952640 1906802338076569600]
# [-4937847358295072768 -6602990316763810816  8211960280831488000
#  -6602990316911450112 -4937847358221252608]
# [ 7016843864742709248 -5185998968048031744   698813195770843136
#  -5185998968638589952  7016843865037987840]
# [ 8275558348783534080   126682784888665104 -2910323242259296256
#    126682782526433312  8275558349964650496]
# [8477604157000558592 7336225513081776128 5180150990053904384
#  7336225503632847872 8477604161725022208]
# [ 6680584151093837824  6016045416121185280 -6423550694767783936
#   6016045378325473280  6680584169991694336]
# [ 7238561252060981248  -115458973918975984 -8807454331021258752
#   -115459125101824992  7238561327652405248]
# [ 8206536867192176640  3484163533226030080 -6076043393679454208
#   3484162928494635008  8206537169557874688]
# [-7186940959123249152  3733268341200201728 -7835642812562829312
#   3733265922274620416 -7186939749660459008]
# [-2406352318421467136   398625702838744064 -8704914548017623040
#    398616027136419840 -2406347480570304512]
#   2777500422250772480 -6774852833026715648]
# [ 9183331505977085952  -941266377855584256    23649251277815840
#   2742678117333481472 -1882012778472222720]
# [ 1811585001877721088 -8195251792800696320 -7060035587760832512
#   6540526187955566592 -5556303988500410368]
# [  677122201464786944 -9124677392100476928 -3903135904151224320
#  -5521797690204080128  8099054387371364352]
# [-6934725650764476416  4570676402275563520  2964420398100660224
#    535451136151599104  4306259019152281600]
# [  412130074856443904  6334257096872835072 -2326855182017740800
#   8640100106086529024  8482580607104372736]
# [-5687948647692447744 -3644106030227441664 -1292614230672523264
#   5579266006627334144  8147109407589715968]
# [-7280689321237098496 -2776672263152060416  7198941841217961984
#  -2776672263152060416 -7280689321237098496]
# [2403263076359786496 8493511749494454272 -549407241097822144
#  8493511749494454272 2403263076359786496]
# [3107942298014109696 7705241228411811840 6946606764992118784
#  7705241228411811840 3107942298014109696]
# [  643185395619123200 -6331333663828789248  5871613519396749312
#  -6331333663828789248   643185395619123200]
# [-4952173230532669440  5964403161454622720  3019478207890866176
#   5964403161454622720 -4952173230532669440]
# [-2540496872872292352  4418924634629289984  5855426737377525760
#   4418924634629289984 -2540496872872292352]
# [-7957385407681605632 -1439889559188785152 -2432717301283405824
#  -1439889559188785152 -7957385407681605632]
# [-8268813051481763840  6653130021786826752 -1836361538283880448
#   6653130021786826752 -8268813051481763840]
# [-7797175428722012160   250959114170808352  4553614148033724416
#    250959114170808352 -7797175428722012160]
# [4283983401266761728 5734245218864150528 8885727968229736448
#  5734245218864150528 4283983401266761728]
# [-1232186194998407168 -6648670248166344704  6699350938071482368
#  -6648670248166344704 -1232186194998407168]
# [-6800712317881757696  9011681258352883712 -2905689984763281408
#   9011681258352883712 -6800712317881757696]
# [ 9140451511293628416 -7622239169768572928  4757548873879011328
#  -7622239169768572928  9140451511293628416]
# [  971831717900111872 -4929283261039560704 -5907008314977927168
#  -4929283261039560704   971831717900111872]
# [ 9132847393303351296  6211458903564761088 -4560601336951980032
#   6211458903564761088  9132847393303351296]
# [ 1258886203726417920  9114619324022077440 -5855943679240945664
#   9114619324022077440  1258886203726417920]
# [ -661407610321317888   297001052672374784 -7118306371027714048
#    297001052672374784  -661407610321317888]
# [ 2314172934028840960 -3778319269028612096  2780441451238408192
#  -3778319269028612096  2314172934028840960]
# [-784685815658000384 1145729036551337984 1228239471941402624
#  1145729036551337984 -784685815658000384]
# [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# Time: 3.426458e-02 seconds
# <ipython-input-7-0ca759080a7f>:9: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)

# %% [markdown]
# Gauss-Seidel Method

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    print(x)
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print(x)
    return x, max_iterations

# %%
# Example usage
A = np.array([[1, 2, 3, 0, 0],
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3],
              [0, 3, 2, 1, 2],
              [0, 0, 3, 2, 1]])
b = np.array([14, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start 

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {elapsed_time:.6e} seconds")
# Out:
# [14 22 33 26 22]
# [-129 -150 -171 -150 -129]
# [ 827 1072 1407 1076  835]
# [-6351 -7674 -9249 -7674 -6351]
# [43109 54244 68835 54248 43117]
# [-314979 -386610 -475629 -386610 -314979]
# [2200121 2741068 3436347 2741072 2200129]
# [-15791163 -19496130 -24164997 -19496130 -15791163]
# [111487265 138400732 172731531 138400736 111487273]
# [ -794996043  -983639778 -1222526517  -983639778  -794996043]
# [5634859121 6985964476 8704535403 6985964480 5634859129]
# [-40085535147 -49636682466 -61753012629 -49636682466 -40085535147]
# [284532402833 352587142972 439059940779 352587142976 284532402841]
# [-2022354108267 -2504946116130 -3117542988885 -2504946116130
#  -2022354108267]
# [14362521198929 17794632542716 22153909114155 17794632542720
#  14362521198937]
# [-102050992427883 -126416758254306 -157353657364437 -126416758254306
#  -102050992427883]
# [ 724894488601937  898059574347580 1117972987584555  898059574347584
#   724894488601945]
# [-5150038111448811 -6379913675415714 -7941605229001941 -6379913675415714
#  -5150038111448811]
# [36584643037837264 45323027707148672 56419883370355752 45323027707148672
#  36584643037837272]
# [-259905705525364576 -321978135937832000 -400799969055618240
#  -321978135937832064 -259905705525364576]
# [1846356179042518784 2287345756975461888 2847346776903515648
#  2287345756975461632 1846356179042518784]
# [ 5330012229048081408  2197300890891097856 -1780776028447408128
#   2197300890891097088  5330012229048081408]
# [  947726303560028672  4756368999834913792 -3875788790433775104
#   4756368999834911744   947726303560030208]
# [ 2114628371631497728 -8412982025757242368 -6265089746990275584
#  -8412982025757251584  2114628371631501824]
# [-1272254854933791744 -3353619319429792768  2517413799530437632
#  -3353619319429828608 -1272254854933773312]
# [-845002759731727360 7570540069096194048 2601262333612386304
#  7570540069096049664 -845002759731655680]
# [-4498123065319995392 -7777395281339915264 -6765399644284786688
#  -7777395281340491776 -4498123065319706624]
# [-1042498651884912640  8965743115811936256  2758087296151265280
#   8965743115809629184 -1042498651883759616]
# [-7759004046368116736  6565081511457510400  7285507595481989120
#   6565081511448283136 -7759004046363502592]
# [1906802338058115072 -301507558863042560 1846954158673719296
#  -301507558899952640 1906802338076569600]
# [-4937847358295072768 -6602990316763810816  8211960280831488000
#  -6602990316911450112 -4937847358221252608]
# [ 7016843864742709248 -5185998968048031744   698813195770843136
#  -5185998968638589952  7016843865037987840]
# [ 8275558348783534080   126682784888665104 -2910323242259296256
#    126682782526433312  8275558349964650496]
# [8477604157000558592 7336225513081776128 5180150990053904384
#  7336225503632847872 8477604161725022208]
# [ 6680584151093837824  6016045416121185280 -6423550694767783936
#   6016045378325473280  6680584169991694336]
# [ 7238561252060981248  -115458973918975984 -8807454331021258752
#   -115459125101824992  7238561327652405248]
