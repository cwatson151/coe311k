# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(True)
# Out:
# True

# %%
2+5
# Out:
# 7

# %%
a = "Hello"
b = True

# %%
str
# Out:
# str

# %%
type(a)
# Out:
# str

# %%
string1 = str(num2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3b6b57638412> in <module>
# ----> 1 string1 = str(num2)
#
# NameError: name 'num2' is not defined

# %%
print(string1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ae13c0f0eacc> in <module>
# ----> 1 print(string1)
#
# NameError: name 'string1' is not defined

# %%
num2 = 5
string1 = str(num2)

# %%
string1
# Out:
# '5'

# %%
myfile = open("test.dat",'w')
myfile.write(myfile, numIn)
myfile.write(myfile, "HelloWorld")
myfile.close()
