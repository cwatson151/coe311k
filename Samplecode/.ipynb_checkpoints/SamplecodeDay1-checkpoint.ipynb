# %%
for r in range(1, 3):
    print(r, r**2)
# Out:
# 1 1
# 2 4

# %%
mylist = ["Clay", 10, "Blue", 15, "Alex", 9, "black", 21]

# %%
for t in mylist:
    print(t)
# Out:
# Clay
# 10
# Blue
# 15
# Alex
# 9
# black
# 21

# %%
print("43" in mylist)
# Out:
# False

# %%
import math

def calc_hyp(a,b):
    h = math.sqrt(a*a + b*b)
    return h

# %%
my_h = calc_hyp(3,4)
print(my_h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-60fa318f0d0c> in <module>
# ----> 1 my_h = calc_hyp(3,4)
#       2 print(my_h)
#
# <ipython-input-6-44deb053408b> in calc_hyp(a, b)
#       2
#       3 def calc_hyp(a,b):
# ----> 4     h = sqrt(a*a, b*b)
#       5     return h
#
# NameError: name 'sqrt' is not defined
