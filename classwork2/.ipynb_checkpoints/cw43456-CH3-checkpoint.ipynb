# %%
import random

value = random.uniform(-1, 1)
print(value)
# Out:
# 0.5120447447495597

# %%
import random

def montecarlo_pi(number_of_shots): 
    for i in range(0,number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if (x*x + y*y < 1):
            number_of_shots = number_of_hits + 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(50)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-47413f1e6965> in <module>
# ----> 1 montecarlo_pi(50)
#
# <ipython-input-2-b44c644a2a8e> in montecarlo_pi(number_of_shots)
#       7
#       8         if (x*x + y*y < 1):
# ----> 9             number_of_hits = number_of_hits + 1
#      10
#      11     return 4*number_of_hits/number_of_shots
#
# UnboundLocalError: local variable 'number_of_hits' referenced before assignment

# %%
import random

def montecarlo_pi(number_of_shots): 
    number_of_hits = 0
    
    for i in range(number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if x*x + y*y < 1:
            number_of_hits += 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(50)
# Out:
# 3.52

# %%
import numpy
import math

for i in range(0,100):
    calculated_pi = montecarlo_pi(1000)
    true_pi = numpy.pi
    true_error = abs(true_pi - calculated_pi)
    relative_error = abs((true_pi - calculated_pi)/(true_pi))

    print(calculated_pi, true_pi)
# Out:
# 3.096 3.141592653589793
# 3.136 3.141592653589793
# 3.116 3.141592653589793
# 3.088 3.141592653589793
# 3.144 3.141592653589793
# 3.136 3.141592653589793
# 3.204 3.141592653589793
# 3.188 3.141592653589793
# 3.176 3.141592653589793
# 3.148 3.141592653589793
# 3.144 3.141592653589793
# 3.052 3.141592653589793
# 3.108 3.141592653589793
# 3.044 3.141592653589793
# 3.048 3.141592653589793
# 3.096 3.141592653589793
# 3.1 3.141592653589793
# 3.144 3.141592653589793
# 3.188 3.141592653589793
# 3.16 3.141592653589793
# 3.048 3.141592653589793
# 3.244 3.141592653589793
# 3.196 3.141592653589793
# 3.072 3.141592653589793
# 3.204 3.141592653589793
# 3.076 3.141592653589793
# 3.128 3.141592653589793
# 3.168 3.141592653589793
# 3.164 3.141592653589793
# 3.144 3.141592653589793
# 3.196 3.141592653589793
# 3.168 3.141592653589793
# 3.04 3.141592653589793
# 3.124 3.141592653589793
# 3.08 3.141592653589793
# 3.16 3.141592653589793
# 3.108 3.141592653589793
# 3.12 3.141592653589793
# 3.036 3.141592653589793
# 3.184 3.141592653589793
# 3.152 3.141592653589793
# 3.168 3.141592653589793
# 3.032 3.141592653589793
# 3.1 3.141592653589793
# 3.152 3.141592653589793
# 3.176 3.141592653589793
# 3.148 3.141592653589793
# 3.036 3.141592653589793
# 3.196 3.141592653589793
# 3.18 3.141592653589793
# 3.192 3.141592653589793
# 3.092 3.141592653589793
# 3.072 3.141592653589793
# 3.128 3.141592653589793
# 3.104 3.141592653589793
# 3.164 3.141592653589793
# 3.116 3.141592653589793
# 3.184 3.141592653589793
# 3.196 3.141592653589793
# 3.104 3.141592653589793
# 3.14 3.141592653589793
# 3.112 3.141592653589793
# 3.132 3.141592653589793
# 3.08 3.141592653589793
# 3.228 3.141592653589793
# 3.156 3.141592653589793
# 3.156 3.141592653589793
# 3.1 3.141592653589793
# 3.068 3.141592653589793
# 3.076 3.141592653589793
# 3.132 3.141592653589793
# 3.084 3.141592653589793
# 3.168 3.141592653589793
# 3.168 3.141592653589793
# 3.156 3.141592653589793
# 3.148 3.141592653589793
# 3.088 3.141592653589793
# 3.128 3.141592653589793
# 3.12 3.141592653589793
# 3.224 3.141592653589793
# 3.1 3.141592653589793
# 3.044 3.141592653589793
# 3.12 3.141592653589793
# 3.204 3.141592653589793
# 3.108 3.141592653589793
# 3.152 3.141592653589793
# 3.18 3.141592653589793
# 3.188 3.141592653589793
# 3.152 3.141592653589793
# 3.096 3.141592653589793
# 3.084 3.141592653589793
# 3.012 3.141592653589793
# 3.104 3.141592653589793
# 3.044 3.141592653589793
# 3.168 3.141592653589793
# 3.116 3.141592653589793
# 3.16 3.141592653589793
# 3.216 3.141592653589793
# 3.124 3.141592653589793
# 3.12 3.141592653589793
