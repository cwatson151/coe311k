# %%
import random

value = random.uniform(-1, 1)
print(value)
# Out:
# 0.5120447447495597

# %%
import random

def montecarlo_pi(number_of_shots): 
    for i in range(0,number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if (x*x + y*y < 1):
            number_of_shots = number_of_hits + 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(50)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-47413f1e6965> in <module>
# ----> 1 montecarlo_pi(50)
#
# <ipython-input-2-b44c644a2a8e> in montecarlo_pi(number_of_shots)
#       7
#       8         if (x*x + y*y < 1):
# ----> 9             number_of_hits = number_of_hits + 1
#      10
#      11     return 4*number_of_hits/number_of_shots
#
# UnboundLocalError: local variable 'number_of_hits' referenced before assignment

# %%
import random

def montecarlo_pi(number_of_shots): 
    for i in range(0,number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if (x*x + y*y < 1):
            number_of_shots = number_of_hits + 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-47413f1e6965> in <module>
# ----> 1 montecarlo_pi(50)
#
# <ipython-input-5-6c08c18ed16b> in montecarlo_pi(number_of_shots)
#       7
#       8         if (x*x + y*y < 1):
# ----> 9             number_of_shots = number_of_hits + 1
#      10
#      11     return 4*number_of_hits/number_of_shots
#
# NameError: name 'number_of_hits' is not defined
